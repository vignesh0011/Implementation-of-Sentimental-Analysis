# %%
pip install vaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.4)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
import pandas as pd
import vaderSentiment as vs

# Read the Excel file
df = pd.read_excel('output.xlsx')

# Create a VADERSentiment object
analyzer = vs.vaderSentiment.SentimentIntensityAnalyzer()

# Calculate the sentiment scores for each text
sentiment_scores = []
for text in df['Text']:
    sentiment_scores.append(analyzer.polarity_scores(text))

# Create a list of the texts
texts = list(df['Text'])

# Display the sentiment scores for each text
for text, sentiment_score in zip(texts, sentiment_scores):
    print("\n\nText:", text)
    print("Positive:", sentiment_score['pos'])
    print("Negative:", sentiment_score['neg'])
    print("Neutral:", sentiment_score['neu'])
    print("Compound:", sentiment_score['compound'])
# Out:
# Text: Congrats to Saudi/PGA/MAGA on the golf merger! Also congrats to sponsors like Comcast, owner of NBC, USA Today Sports, Amazon Web Services, representing the Washington Post and Jamal Khashoggi, Citibank, which lost 6 employees on 9/11, with 16K who were…
# https://t.co/5NDtFnF91k
# Positive: 0.228
# Negative: 0.046
# Neutral: 0.726
# Compound: 0.8398
#
#
# Text: Pakistani wicket-keeper #MohammadRizwan stops his car to offer namaz on the street in Boston, US. Pak captain Babar Azam and Muhammad Rizwan are in the US to attend Harvard’s executive education program on the Business of Entertainment, Media and Sports. https://t.co/Qd2ODUKZzk
# Positive: 0.065
# Negative: 0.037
# Neutral: 0.899
# Compound: 0.296
#
#
# Text: $100 ($25 X 4) || 24 Hours
#
# ✅ RT & comment your favourite Game/sports
#
# (Promo 9/20 for 2k)
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: Michael Copeland to succeed @JJL_Sports as CEO of @WoodbineTB Entertainment - Toronto | https://t.co/Jt1IlCphs5 https://t.co/nCeDgeISCz #CFL #Ticats
# Positive: 0.286
# Negative: 0.0
# Neutral: 0.714
# Compound: 0.7184
#
#
# Text: RT @NEARProtocol: From Athletics to Art-letics: The Future of #NFTs  and Sports Fandom with @BaronDavis, @ysiu, @joespano_  🏅
#
# Live now on…
# Positive: 0.129
# Negative: 0.0
# Neutral: 0.871
# Compound: 0.4767
#
#
# Text: Happy Birthday @redzoneinthelab Best Commanders Podcaster Out there #HTTC #RITL #405Crew #CCT https://t.co/hUksvVnXNO
# Positive: 0.418
# Negative: 0.0
# Neutral: 0.582
# Compound: 0.836
#
#
# Text: The planet’s best player will be joining Major League Soccer. Here’s where you can watch him.  https://t.co/j3gqQtt4nf
# Positive: 0.208
# Negative: 0.0
# Neutral: 0.792
# Compound: 0.6369
#
#
# Text: LIVE from Madison Square Garden!
#
# Tune in below to join us and learn more about Don't Quit! This sports nutrition brand is the first of its kind to offer clean and healthy products without any artificial ingredients!
#
# https://t.co/ihoH4wfWjf
#
# #investing #PrivateEquity https://t.co/6VUwCS2vYX
# Positive: 0.243
# Negative: 0.0
# Neutral: 0.757
# Compound: 0.8974
#
#
# Text: Adams looked noticeably bigger, particularly in his upper body, at Seattle’s minicamp. He and Brooks have been in Texas rehabbing.  https://t.co/W1EGMVps0S
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: The planet’s best player will be joining Major League Soccer. Here’s where you can watch him.  https://t.co/e5Sew17zXA
# Positive: 0.208
# Negative: 0.0
# Neutral: 0.792
# Compound: 0.6369
#
#
# Text: Her husband is worth over $500 million.
#
# https://t.co/lRSl6IMxFc
# Positive: 0.213
# Negative: 0.0
# Neutral: 0.787
# Compound: 0.2263
#
#
# Text: LIV golfers are soaking in the moment https://t.co/bJZaaYMMCp
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @UHFan79: ⁦@UHCougarMBK⁩  ⁦@ChronSports⁩
# UH basketball makes the front page!
# UH Cougars men's basketball begins summer workouts on Mo…
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @HeatvsHaters: Heat in the Finals.
# Panthers in the Stanley Cup.
# Messi to Inter Miami.
# McDaniel running the Dolphins.
#
# South Florida…
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: Looking for info on summer workouts, fall tryouts, coach contact info, and PlanetHS help?  Scan the QR code for more!
#
# or use this link:
# https://t.co/wncz4hSztk? https://t.co/Pa9mk7WlIx
# Positive: 0.118
# Negative: 0.0
# Neutral: 0.882
# Compound: 0.5191
#
#
# Text: RT @MySportsUpdate: The #Jaguars have unveiled their renovation plans for TIAA Bank Field.
#
# The plan is to transform Downtown Jacksonville…
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: The Bucks went against the grain by selecting Adrian Griffin, who spent the last five seasons as an assistant with Toronto. https://t.co/HI2TWyhyzY
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: @HoffWFAN bro you got to reach out to sports stations in Seattle. They have a crazy obsession abd love for Vogelbach. Maybe they'll help get to get him to the ASG?
# Positive: 0.206
# Negative: 0.124
# Neutral: 0.67
# Compound: 0.4939
#
#
# Text: 📢🚨 Brandon King, Johnson Charles star as West Indies clinch ODI series against UAE
#
# ➡️ Read more: https://t.co/zkWhEYdyjv via ESPN
#
# 🚀 FOLLOW @HalftimesUK to get all the latest #Cricket News for UK
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: @grassrootsrefJa @sparkyfenton @FAspokesperson @LUFC @premierleague Had Sky Sports been able to capture FFP rule breaches on a live broadcast that also may help 🤣
# Positive: 0.185
# Negative: 0.0
# Neutral: 0.815
# Compound: 0.7096
#
#
# Text: Golf: Brilliant round gives Jaraula lead at Valley Golf
# https://t.co/d2epv9Wu5L
# Positive: 0.297
# Negative: 0.0
# Neutral: 0.703
# Compound: 0.5859
#
#
# Text: RT @votetimscott: If you are able-bodied, you work.
#
# If you take out a loan, you pay it back.
#
# If you commit a violent crime, you go to jai…
# Positive: 0.063
# Negative: 0.251
# Neutral: 0.686
# Compound: -0.765
#
#
# Text: There’s some kind of jihad on St. Louis sports this year, man https://t.co/sfJfet2ZC6
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: I’m glad this show finna end man skip and Shannon both know nothing about sports, Shannon knows a little football but that’s it https://t.co/T4mrheyIEx
# Positive: 0.08
# Negative: 0.0
# Neutral: 0.92
# Compound: 0.25
#
#
# Text: Week #2!  Another level!  TRAIN FOR CHANGE!  Coach Rozy Performance - Powered by AVERA Sports Yankton https://t.co/whEQU4RLFe
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @JohnJHarwood: "When Khashoggi spoke against the state, he was lured to a Saudi consulate, drugged and cut into pieces.
#
# "Who did it? Ac…
# Positive: 0.0
# Negative: 0.084
# Neutral: 0.916
# Compound: -0.2732
#
#
# Text: RT @BillKristol: “Even in the rich annals of the sports world’s greed and hypocrisy, the PGA announcement Tuesday stands out as a special s…
# Positive: 0.21
# Negative: 0.09
# Neutral: 0.7
# Compound: 0.5574
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
